# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import os, json, math, librosa

import IPython.display as ipd
import librosa.display

import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D

import sklearn.model_selection as sk

from sklearn.model_selection import train_test_split

# %%
MUSIC = '/content/drive/MyDrive/Data/genres_original/'
music_dataset = [] # File locations for each wav file 
genre_target = [] 
for root, dirs, files in os.walk(MUSIC):
    for name in files:
        filename = os.path.join(root, name)
        if filename != '/content/drive/MyDrive/Data/genres_original/jazz/jazz.00054.wav':
            music_dataset.append(filename)
            genre_target.append(filename.split("/")[5])

# %%
print(set(genre_target))
# Out:
# {'genres_original'}

# %%
audio_path = music_dataset[500]
# img_path = './data/images_original/blues/blues00011.png'

x , sr = librosa.load(audio_path)



librosa.load(audio_path, sr=None)

ipd.Audio(audio_path)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Visualizing Audio File as a waveform
plt.figure(figsize=(16, 7), facecolor= 'white', dpi = 60)
librosa.display.waveplot(x, sr=sr)

# %%
# Visualizing audio file as a spectogram
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(16, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.title('Spectogram')
plt.colorbar()

# %%
# Visualizing Audio as Mel-Spectogram

file_location = audio_path
y, sr = librosa.load(file_location)
melSpec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
melSpec_dB = librosa.power_to_db(melSpec, ref=np.max)
plt.figure(figsize=(10, 5))
librosa.display.specshow(melSpec_dB, x_axis='time', y_axis='mel', sr=sr, fmax=6000)
plt.colorbar(format='%+1.0f dB')
plt.title("MelSpectrogram")
plt.tight_layout()
plt.show()

# %%
DATASET_PATH = '/content/drive/MyDrive/Data/genres_original/'
JSON_PATH = "data_10.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file

                file_path = os.path.join(dirpath, f)
            
                if file_path != '/content/drive/MyDrive/Data/genres_original/jazz/jazz.00054.wav':

                    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
                
                
                    # process all segments of audio file
                    for d in range(num_segments):

                        # calculate start and finish sample for current segment
                        start = samples_per_segment * d
                        finish = start + samples_per_segment

                        # extract mfcc
                        mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = mfcc.T

                        # store only mfcc feature with expected number of vectors
                        if len(mfcc) == num_mfcc_vectors_per_segment:
                            data["mfcc"].append(mfcc.tolist())
                            data["labels"].append(i-1)
                            print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
# Runs Data Processing     
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=6)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/Data/genres_original/classical/classical.00066.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00066.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00066.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00066.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00066.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00066.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00070.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00070.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00070.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00070.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00070.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00070.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00068.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00068.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00068.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00068.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00068.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00068.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00069.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00069.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00069.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00069.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00069.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00069.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00071.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00071.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00071.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00071.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00071.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00071.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00074.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00074.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00074.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00074.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00074.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00074.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00067.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00067.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00067.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00067.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00067.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00067.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00075.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00075.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00075.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00075.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00075.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00075.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00073.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00073.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00073.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00073.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00073.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00073.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00087.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00087.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00087.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00087.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00087.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00087.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00081.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00081.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00081.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00081.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00081.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00081.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00085.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00085.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00085.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00085.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00085.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00085.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00078.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00078.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00078.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00078.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00078.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00078.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00082.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00082.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00082.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00082.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00082.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00082.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00084.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00084.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00084.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00084.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00084.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00084.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00088.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00088.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00088.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00088.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00088.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00088.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00079.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00079.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00079.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00079.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00079.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00079.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00086.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00086.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00086.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00086.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00086.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00086.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00080.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00080.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00080.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00080.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00080.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00080.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00083.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00083.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00083.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00083.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00083.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00083.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00093.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00093.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00093.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00093.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00093.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00093.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00098.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.00098.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/classical/classical.00098.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/classical/classical.00098.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/classical/classical.00098.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/classical/classical.00098.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/classical/classical.00099.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/classical/classical.
# add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)
    
    # get mappings for target and predicted label
    target = z[y]
    predicted = z[predicted_index]

    print("Target: {}, Predicted label: {}".format(target, predicted))

# %%
# get train, validation, test splits
X_train, X_validation, X_test, y_train, y_validation, y_test, z = prepare_datasets(0.25, 0.2)

# create network
input_shape = (X_train.shape[1], X_train.shape[2], 1)
model = build_model(input_shape)

# compile model
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 214, 11, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 107, 6, 32)       0
#  )
#
#  batch_normalization (BatchN  (None, 107, 6, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 105, 4, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 2, 32)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 53, 2, 32)        128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 52, 1, 32)         4128
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 1, 32)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 26, 1, 32)        128
#  hNormalization)
#
#  flatten (Flatten)           (None, 832)               0
#
#  dense (Dense)               (None, 64)                53312
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 68,042
# Trainable params: 67,850
# Non-trainable params: 192
# _________________________________________________________________

# %%
# train model
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=35)
# Out:
# Epoch 1/35
# 113/113 [==============================] - 12s 109ms/step - loss: 0.5063 - accuracy: 0.8292 - val_loss: 0.8960 - val_accuracy: 0.7008
# Epoch 2/35
# 113/113 [==============================] - 12s 109ms/step - loss: 0.4753 - accuracy: 0.8423 - val_loss: 0.9207 - val_accuracy: 0.6941
# Epoch 3/35
# 113/113 [==============================] - 13s 112ms/step - loss: 0.4912 - accuracy: 0.8392 - val_loss: 0.9261 - val_accuracy: 0.7097
# Epoch 4/35
# 113/113 [==============================] - 12s 105ms/step - loss: 0.4616 - accuracy: 0.8465 - val_loss: 0.8844 - val_accuracy: 0.7141
# Epoch 5/35
# 113/113 [==============================] - 12s 105ms/step - loss: 0.4647 - accuracy: 0.8459 - val_loss: 0.9233 - val_accuracy: 0.7041
# Epoch 6/35
# 113/113 [==============================] - 12s 104ms/step - loss: 0.4424 - accuracy: 0.8512 - val_loss: 0.9209 - val_accuracy: 0.6963
# Epoch 7/35
# 113/113 [==============================] - 12s 105ms/step - loss: 0.4275 - accuracy: 0.8609 - val_loss: 0.8917 - val_accuracy: 0.7008
# Epoch 8/35
# 113/113 [==============================] - 12s 106ms/step - loss: 0.4127 - accuracy: 0.8656 - val_loss: 0.8779 - val_accuracy: 0.7152
# Epoch 9/35
# 113/113 [==============================] - 13s 114ms/step - loss: 0.4006 - accuracy: 0.8690 - val_loss: 0.9497 - val_accuracy: 0.6874
# Epoch 10/35
# 113/113 [==============================] - 12s 102ms/step - loss: 0.4006 - accuracy: 0.8668 - val_loss: 0.9373 - val_accuracy: 0.6796
# Epoch 11/35
# 113/113 [==============================] - 13s 117ms/step - loss: 0.3810 - accuracy: 0.8743 - val_loss: 0.9389 - val_accuracy: 0.7119
# Epoch 12/35
# 113/113 [==============================] - 12s 104ms/step - loss: 0.3685 - accuracy: 0.8804 - val_loss: 0.8998 - val_accuracy: 0.7130
# Epoch 13/35
# 113/113 [==============================] - 11s 101ms/step - loss: 0.3657 - accuracy: 0.8790 - val_loss: 0.8949 - val_accuracy: 0.7041
# Epoch 14/35
# 113/113 [==============================] - 11s 102ms/step - loss: 0.3563 - accuracy: 0.8818 - val_loss: 0.9299 - val_accuracy: 0.6986
# Epoch 15/35
# 113/113 [==============================] - 11s 101ms/step - loss: 0.3361 - accuracy: 0.8932 - val_loss: 0.9247 - val_accuracy: 0.7075
# Epoch 16/35
# 113/113 [==============================] - 11s 102ms/step - loss: 0.3327 - accuracy: 0.8949 - val_loss: 0.9093 - val_accuracy: 0.7186
# Epoch 17/35
# 113/113 [==============================] - 11s 102ms/step - loss: 0.3177 - accuracy: 0.8962 - val_loss: 0.9280 - val_accuracy: 0.7119
# Epoch 18/35
# 113/113 [==============================] - 11s 102ms/step - loss: 0.3195 - accuracy: 0.8946 - val_loss: 0.9001 - val_accuracy: 0.7175
# Epoch 19/35
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2999 - accuracy: 0.9063 - val_loss: 0.8686 - val_accuracy: 0.7297
# Epoch 20/35
# 113/113 [==============================] - 11s 102ms/step - loss: 0.3019 - accuracy: 0.9051 - val_loss: 0.9481 - val_accuracy: 0.7019
# Epoch 21/35
# 113/113 [==============================] - 11s 101ms/step - loss: 0.3019 - accuracy: 0.9060 - val_loss: 0.8871 - val_accuracy: 0.7275
# Epoch 22/35
# 113/113 [==============================] - 11s 102ms/step - loss: 0.2689 - accuracy: 0.9132 - val_loss: 0.8946 - val_accuracy: 0.7253
# Epoch 23/35
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2804 - accuracy: 0.9157 - val_loss: 0.9024 - val_accuracy: 0.7041
# Epoch 24/35
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2663 - accuracy: 0.9199 - val_loss: 0.8859 - val_accuracy: 0.7141
# Epoch 25/35
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2584 - accuracy: 0.9229 - val_loss: 0.9168 - val_accuracy: 0.7197
# Epoch 26/35
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2565 - accuracy: 0.9277 - val_loss: 0.8828 - val_accuracy: 0.7253
# Epoch 27/35
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2500 - accuracy: 0.9257 - val_loss: 0.9092 - val_accuracy: 0.7353
# Epoch 28/35
# 113/113 [==============================] - 11s 102ms/step - loss: 0.2488 - accuracy: 0.9213 - val_loss: 0.9061 - val_accuracy: 0.7197
# Epoch 29/35
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2378 - accuracy: 0.9243 - val_loss: 0.9573 - val_accuracy: 0.7097
# Epoch 30/35
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2207 - accuracy: 0.9327 - val_loss: 0.8850 - val_accuracy: 0.7286
# Epoch 31/35
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2465 - accuracy: 0.9246 - val_loss: 0.9492 - val_accuracy: 0.7130
# Epoch 32/35
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2261 - accuracy: 0.9291 - val_loss: 0.9424 - val_accuracy: 0.7075
# Epoch 33/35
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2154 - accuracy: 0.9377 - val_loss: 0.9309 - val_accuracy: 0.7264
# Epoch 34/35
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2087 - accuracy: 0.9382 - val_loss: 0.9073 - val_accuracy: 0.7130
# Epoch 35/35
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2031 - accuracy: 0.9419 - val_loss: 0.9431 - val_accuracy: 0.7186

# %%
# plot accuracy/error for training and validation
plot_history(history)

# %%
# evaluate model on test set
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc*100)
# Out:
# 47/47 - 1s - loss: 0.9697 - accuracy: 0.7143 - 988ms/epoch - 21ms/step
#
# Test accuracy: 71.42857313156128

# %%
# pick a sample to predict from the test set
X_to_predict = X_test[100]
y_to_predict = y_test[100]

# predict sample
predict(model, X_to_predict, y_to_predict)
# Out:
# Target: metal, Predicted label: ['metal']
